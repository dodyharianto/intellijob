# %%
import serpapi
from dotenv import load_dotenv
import pandas as pd
import os

load_dotenv()
SERPAPI_API_KEY = os.getenv('SERPAPI_API_KEY')
client = serpapi.Client(api_key=SERPAPI_API_KEY)

# %%
def scrape_google_jobs(query):
    search_params = {
        "engine": "google_jobs",
        "q": query,
        "hl": "en",
        "location": "Singapore",
        "api_key": SERPAPI_API_KEY
    }

    results = serpapi.search(**search_params)
    print(results)

    jobs_results = results["jobs_results"]
    jobs_results_df = pd.DataFrame(jobs_results)
    return jobs_results_df

preferred_role = 'AI Engineer'
results = scrape_google_jobs(query=preferred_role)
# Out:
# {
#     "search_metadata": {
#         "id": "69515365bca7e53381302c91",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/256b043477b7d259/69515365bca7e53381302c91.json",
#         "created_at": "2025-12-28 15:57:25 UTC",
#         "processed_at": "2025-12-28 15:57:25 UTC",
#         "google_jobs_url": "https://www.google.com/search?q=AI+Engineer&uule=w+CAIQICIJU2luZ2Fwb3Jl&hl=en&udm=8",
#         "raw_html_file": "https://serpapi.com/searches/256b043477b7d259/69515365bca7e53381302c91.html",
#         "total_time_taken": 2.81
#     },
#     "search_parameters": {
#         "q": "AI Engineer",
#         "engine": "google_jobs",
#         "location_requested": "Singapore",
#         "location_used": "Singapore",
#         "google_domain": "google.com",
#         "hl": "en"
#     },
#     "filters": [
#         {
#             "name": "No degree",
#             "parameters": {
# ...

# %%
results
# Out:
#                                                title  \
# 0                                        AI Engineer
# 1             (Senior) AI Engineer - BCG X Singapore
# 2                                        AI Engineer
# 3  Artificial Intelligence Engineer (Azure OpenAI...
# 4  Junior AI Engineers (Associates/Senior Associa...
# 5                 Associate, AI Engineer (Singapore)
# 6          AI Engineer, Artificial Intelligence, GEC
# 7                    Solutions Engineer - Cloud & AI
# 8                        AI Engineer, Digital Energy
# 9  Software Engineer 2 - AI Infra and Platform En...
#
#                                        company_name   location  \
# 0                                          HEINEKEN  Singapore
# 1                           Boston Consulting Group  Singapore
# 2                                              Zoom  Singapore
# 3                                Avensys Consulting  Singapore
# ...

# %%
def scrape_google_jobs(query):
    search_params = {
        "engine": "google_jobs",
        "q": query,
        "hl": "en",
        "location": "Singapore",
        "api_key": SERPAPI_API_KEY
    }

    results = serpapi.search(**search_params)
    jobs_results = results["jobs_results"]

    next_page_tokens = 0
    while True:
        results = serpapi.search(**search_params)
        if 'job_results' not in results:
            print('No more job results. ❌')
            break
        next_page_tokens += 10
    jobs_results = results['jobs_results']
    return jobs_results

# %%
scrape_google_jobs('Data Scientist')
# Out:
# No more job results. ❌
# [{'title': 'Staff Data Scientist (Relo to SF) | Singapore, SG',
#   'company_name': 'Airwallex',
#   'location': 'Singapore',
#   'via': 'EFinancialCareers SG',
#   'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=Data+Scientist&htidocid=CzUUHss5JdrreE1YAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_0XNsQrCMBAAUFz7AQ5ON6poI4JLnQSx4mg-oFzDNY3EXMgd2MF_8VfFyeWtr_rMqqtVHAY4oyJYFyhpEIXlnSKDMtjLCt5gQ_KYudAGbAtbuHEPQljcCJygZfaRFsdRNUtjjEisvShqcLXjp-FEPU_mwb386GTEQjmiUrc_7KY6J7-en0J5YYw0QUj_7wtjvDPAogAAAA&shmds=v1_AdeF8KiU98N59-JhNU5tMtzLJYHdWS9-OT0F7aWerssBfAJB3Q&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=Data+Scientist&htidocid=CzUUHss5JdrreE1YAAAAAA%3D%3D',
#   'thumbnail': 'https://serpapi.com/searches/6951574866bc788cab4c662d/images/e994f1c370e0337ba5c045cedd0646a00d7e4a17a93c37de9737efd647eb1d40.jpeg',
#   'extensions': ['1 day ago', 'Full-time'],
#   'detected_extensions': {'posted_at': '1 day ago',
# ...

# %% [markdown]
# Check results in dataframe format.

# %%
import pandas as pd
import serpapi
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()
SERPAPI_API_KEY = os.getenv('SERPAPI_API_KEY') 

client = OpenAI()

def get_refined_search_query(user_query: str):
    system_prompt = """
    You are an expert in extracting interpreting the preferred job position/role based on user input.
    Only output a clear job position to be used for Google search.
    """

    response = client.responses.create(
        model='gpt-5-nano',
        input=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_query}
        ]
    )

    search_query = response.output_text
    return search_query

def scrape_google_jobs(query: str):
    refined_query = get_refined_search_query(query)
    print(f'Searching for: {refined_query}')
    search_params = {
        "engine": "google_jobs",
        "q": refined_query,
        "hl": "en",
        "location": "Singapore",
        "api_key": SERPAPI_API_KEY
    }

    results = serpapi.search(**search_params)
    jobs_results = results["jobs_results"]
    jobs_results_df = pd.DataFrame(jobs_results)
    return jobs_results_df

# %%
query = 'find me ai engineer jobs in singapore'
jobs_results_df = scrape_google_jobs(query)
jobs_results_df
# Out:
# Searching for: AI Engineer Singapore
#                                                title  \
# 0                 Associate, AI Engineer (Singapore)
# 1           Senior/Lead AI Engineer, BCG X Singapore
# 2                                        AI Engineer
# 3  Engineer / Lead Engineer, Applied Vision AI R&...
# 4                Senior Machine Learning/AI Engineer
# 5                        AI Engineer, Digital Energy
# 6                      AI Platform Engineer - ML Ops
# 7             (Senior) AI Engineer - BCG X Singapore
# 8                    Solutions Engineer - Cloud & AI
# 9                            AI/ML Engineer-Contract
#
#                                     company_name   location  \
# 0                          Nomura Holdings, inc.  Singapore
# 1                        Boston Consulting Group  Singapore
# 2                                           Zoom  Singapore
# 3  Home Team Science and Technology Agency (HTX)  Singapore
# ...

# %%
query = 'find me ai engineer internships in singapore'
jobs_results_df = scrape_google_jobs(query)
jobs_results_df
# Out:
# Searching for: AI Engineer Internship Singapore
#                                                title  \
# 0                        Building AI Engineer Intern
# 1          Machine Learning and Generative AI Intern
# 2                                 AI Engineer Intern
# 3  Summer Internship 2026 - AI and Gen AI Specialist
# 4           AI Researcher Intern (Embodied Robotics)
# 5                          CPS SG AI Engineer Intern
# 6                         AI Systems Engineer Intern
# 7      Internship: Data/AI Engineer (May - Aug 2024)
# 8  Computer Vision Model Engineer Intern (Jan/Feb...
# 9  AI Engineering Intern (Computer Vision & Deep ...
#
#                company_name   location                 via  \
# 0        Schneider Electric  Singapore  Schneider Electric
# 1        Seagate Technology  Singapore     Seagate Careers
# 2             Singtel Group  Singapore      Singtel Career
# 3  Income Insurance Limited  Singapore              Indeed
# ...

# %%
jobs_results_df['extensions']
# Out:
# 0                           [Full-time and Internship]
# 1                            [15 days ago, Internship]
# 2                            [18 days ago, Internship]
# 3                              [4 days ago, Full-time]
# 4    [5 days ago, SGD 1.2K–SGD 1.8K a month, Intern...
# 5                            [23 days ago, Internship]
# 6                [SGD 2K–SGD 2.5K a month, Internship]
# 7                                         [Internship]
# 8                            [11 days ago, Internship]
# 9              [SGD 1.1K–SGD 1.5K a month, Internship]
# Name: extensions, dtype: object

# %%
jobs_results_df['detected_extensions']
# Out:
# 0        {'schedule_type': 'Full-time and Internship'}
# 1    {'posted_at': '15 days ago', 'schedule_type': ...
# 2    {'posted_at': '18 days ago', 'schedule_type': ...
# 3    {'posted_at': '4 days ago', 'schedule_type': '...
# 4    {'posted_at': '5 days ago', 'salary': 'SGD 1.2...
# 5    {'posted_at': '23 days ago', 'schedule_type': ...
# 6    {'salary': 'SGD 2K–SGD 2.5K a month', 'schedul...
# 7                      {'schedule_type': 'Internship'}
# 8    {'posted_at': '11 days ago', 'schedule_type': ...
# 9    {'salary': 'SGD 1.1K–SGD 1.5K a month', 'sched...
# Name: detected_extensions, dtype: object

# %%
jobs_results_df['extensions'].iloc[4]
# Out:
# ['5 days ago', 'SGD\xa01.2K–SGD\xa01.8K a month', 'Internship']

# %%
jobs_results_df['detected_extensions'].iloc[3]
# Out:
# {'posted_at': '4 days ago', 'schedule_type': 'Full-time'}

# %%
salary = jobs_results_df['detected_extensions'].iloc[4].get('salary')
posted_at = jobs_results_df['detected_extensions'].iloc[4].get('posted_at')

salary, posted_at
# Out:
# ('SGD 1.2K–SGD 1.8K a month', '5 days ago')

# %% [markdown]
# # Pydantic

# %% [markdown]
# Pydantic is used for validation and quality control to ensure data consistency.

# %%
from pydantic import BaseModel
from typing import List, Optional

class JobResult(BaseModel):
    title: str
    company: str
    location: str
    link: str
    description: str
    salary: Optional[str] = None
    posted_at: Optional[str] = None

# %%
def scrape_google_jobs(query: str):
    refined_query = get_refined_search_query(query)
    print(f'Searching for: {refined_query}')
    search_params = {
        "engine": "google_jobs",
        "q": refined_query,
        "hl": "en",
        "location": "Singapore",
        "api_key": SERPAPI_API_KEY
    }

    results = serpapi.search(**search_params)
    jobs_results = results["jobs_results"]
    jobs_results_df = pd.DataFrame(jobs_results)

    clean_jobs = []
    for idx, row in jobs_results_df.iterrows():
        job = JobResult(
            title=row['title'],
            company=row['company_name'],
            location=row['location'],
            link=row['share_link'],
            description=row['description'],
            salary=row['detected_extensions'].get('salary'),
            posted_at=row['detected_extensions'].get('posted_at')
        )
        clean_jobs.append(job)

    return clean_jobs

# %%
query = 'find me ai engineer internships in singapore'
jobs = scrape_google_jobs(query)
jobs
# Out:
# Searching for: AI Engineer Internships Singapore
# ...

# %%
import json

json.loads(jobs[0].model_dump_json())
# Out:
# {'title': 'Building AI Engineer Intern',
#  'company': 'Schneider Electric',
#  'location': 'Singapore',
#  'link': 'https://www.google.com/search?ibp=htl;jobs&q=AI+Engineer+Internships+Singapore&htidocid=DadXvTo8Iylc87d0AAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xXOsQrCMBCAYVz7CC7eLNhIwUUnhSJ17QOUND2Sk3gXcif0OXxidfnX728-m6a7vSkvxBGuA_QciRErDGxYGQ7wkBkUfQ0JhOEuEjNuL8ms6Nk51dxGNW8U2iAvJ4yzrO4ps_4zafIVS_aGU3c6rm3huN-NITHS8lP6jMEqBSCG8bfgi1T8AuL8N8-VAAAA&shmds=v1_AdeF8KhCca_MmrgCy7a9dEsnd5WbJcoCeI3CLWrZxct5m1jHjQ&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=AI+Engineer+Internships+Singapore&htidocid=DadXvTo8Iylc87d0AAAAAA%3D%3D',
# ...

# %% [markdown]
# Convert raw JSON consisting of jobs (extracted from SerpAPI) into Pydantic objects.

# %%
search_params = {
    "engine": "google_jobs",
    "q": 'Machine Learning Engineer',
    "hl": "en",
    "location": "Singapore",
    "api_key": SERPAPI_API_KEY
}

results = serpapi.search(**search_params)
jobs_results = results.get('jobs_results')
jobs_results
# Out:
# [{'title': 'Principal Machine Learning System Engineer',
#   'company_name': 'Atlassian',
#   'location': 'Singapore',
#   'via': 'Join Our Talent Community | Atlassian Careers Apply - Atlassian',
#   'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=Machine+Learning+Engineer&htidocid=hmrzybxb-pIZD7iaAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xWNMQrCQBAAsc0DLKy2FsyJYKNViiCIgpAHhM2x3K1cdo_bK-JPfK6xmWKmmOa7abpXYfGcMcETfWQheBAWYQkwfKzSDL2EVVOBA9x1Aluzj6ACN9WQaHeNtWa7OGeW2mAVK_vW6-xUaNLFvXWyP0aLWCgnrDSezselzRL2264mNGMUYIFh3WLWQj8wJe5lmwAAAA&shmds=v1_AdeF8KgrPu3QG_JOgGfeSmSElJhhiLI16JeRz-fSgfPRagzIvw&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=Machine+Learning+Engineer&htidocid=hmrzybxb-pIZD7iaAAAAAA%3D%3D',
#   'extensions': ['Full-time'],
#   'detected_extensions': {'schedule_type': 'Full-time'},
# ...

# %%
for job in jobs_results:
    print(job)
# Out:
# {'title': 'Principal Machine Learning System Engineer', 'company_name': 'Atlassian', 'location': 'Singapore', 'via': 'Join Our Talent Community | Atlassian Careers Apply - Atlassian', 'share_link': 'https://www.google.com/search?ibp=htl;jobs&q=Machine+Learning+Engineer&htidocid=hmrzybxb-pIZD7iaAAAAAA%3D%3D&hl=en-US&shndl=37&shmd=H4sIAAAAAAAA_xWNMQrCQBAAsc0DLKy2FsyJYKNViiCIgpAHhM2x3K1cdo_bK-JPfK6xmWKmmOa7abpXYfGcMcETfWQheBAWYQkwfKzSDL2EVVOBA9x1Aluzj6ACN9WQaHeNtWa7OGeW2mAVK_vW6-xUaNLFvXWyP0aLWCgnrDSezselzRL2264mNGMUYIFh3WLWQj8wJe5lmwAAAA&shmds=v1_AdeF8KgrPu3QG_JOgGfeSmSElJhhiLI16JeRz-fSgfPRagzIvw&source=sh/x/job/li/m1/1#fpstate=tldetail&htivrt=jobs&htiq=Machine+Learning+Engineer&htidocid=hmrzybxb-pIZD7iaAAAAAA%3D%3D', 'extensions': ['Full-time'], 'detected_extensions': {'schedule_type': 'Full-time'}, 'description': 'Overview\n\nWorking at Atlassian\n\nAtlassians can choose where they work – whether in an office, from home, or a combination of the two. That way, Atlassians have more con
# ...

# %%
import pandas as pd
import serpapi
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()
SERPAPI_API_KEY = os.getenv('SERPAPI_API_KEY') 

client = OpenAI()

def get_refined_search_query(user_query: str):
    system_prompt = """
    You are an expert in extracting interpreting the preferred job position/role based on user input.
    Only output a clear job position to be used for Google search.
    """

    response = client.responses.create(
        model='gpt-5-nano',
        input=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_query}
        ]
    )

    search_query = response.output_text
    return search_query

def scrape_google_jobs(query: str):
    refined_query = get_refined_search_query(query)
    print(f'Searching for: {refined_query}')
    search_params = {
        "engine": "google_jobs",
        "q": refined_query,
        "hl": "en",
        "location": "Singapore",
        "api_key": SERPAPI_API_KEY
    }

    results = serpapi.search(**search_params)
    jobs_results = results.get('jobs_results')

    clean_jobs = []
    for job in jobs_results:
        clean_job = JobResult(
            title=job['title'],
            company=job['company_name'],
            location=job['location'],
            link=job['share_link'],
            description=job['description'],
            salary=job['detected_extensions'].get('salary'),
            posted_at=job['detected_extensions'].get('posted_at')
        )
        clean_jobs.append(clean_job)

    return clean_jobs

# %%
query = 'find me ai engineer internships in singapore'
jobs = scrape_google_jobs(query)
jobs
# Out:
# Searching for: AI Engineer Internship in Singapore
# ...
